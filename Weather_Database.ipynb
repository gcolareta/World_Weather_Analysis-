# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the time library
import time

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
weather_data=[]
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(2)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        print(city_description)
        # Append the city information into city_data list.
        weather_data.append({"City": city.title(),
                             "Country": city_country,
                             "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,
                             "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# few clouds
# Processing Record 2 of Set 1 | kahului
# scattered clouds
# Processing Record 3 of Set 1 | vila velha
# few clouds
# Processing Record 4 of Set 1 | bayeux
# broken clouds
# Processing Record 5 of Set 1 | narsaq
# few clouds
# Processing Record 6 of Set 1 | victoria
# broken clouds
# Processing Record 7 of Set 1 | paamiut
# overcast clouds
# Processing Record 8 of Set 1 | busselton
# scattered clouds
# Processing Record 9 of Set 1 | mecca
# few clouds
# Processing Record 10 of Set 1 | new norfolk
# overcast clouds
# Processing Record 11 of Set 1 | harper
# broken clouds
# Processing Record 12 of Set 1 | hermanus
# clear sky
# Processing Record 13 of Set 1 | mar del plata
# clear sky
# Processing Record 14 of Set 1 | natal
# scattered clouds
# Processing Record 15 of Set 1 | seymchan
# scattered clouds
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | rikitea
# clear sky
# Processing Record 18 of Set 1 | asyut
# clear sky
# Processing Record 19 of Set 1 | barra
# clear sky
# Processing Record 20 of Set 1 | tuktoyaktuk
# overcast clouds
# Processing Record 21 of Set 1 | bud
# few clouds
# Processing Record 22 of Set 1 | lebu
# broken clouds
# Processing Record 23 of Set 1 | bubaque
# broken clouds
# Processing Record 24 of Set 1 | nanortalik
# clear sky
# Processing Record 25 of Set 1 | albany
# overcast clouds
# Processing Record 26 of Set 1 | port lincoln
# scattered clouds
# Processing Record 27 of Set 1 | butaritari
# light rain
# Processing Record 28 of Set 1 | mataura
# broken clouds
# Processing Record 29 of Set 1 | lazaro cardenas
# overcast clouds
# Processing Record 30 of Set 1 | corn island
# scattered clouds
# Processing Record 31 of Set 1 | port blair
# overcast clouds
# Processing Record 32 of Set 1 | jamestown
# clear sky
# Processing Record 33 of Set 1 | yellowknife
# scattered clouds
# Processing Record 34 of Set 1 | bilibino
# overcast clouds
# Processing Record 35 of Set 1 | lasa
# clear sky
# Processing Record 36 of Set 1 | mezen
# overcast clouds
# Processing Record 37 of Set 1 | ouesso
# overcast clouds
# Processing Record 38 of Set 1 | wanaka
# overcast clouds
# Processing Record 39 of Set 1 | lagoa
# few clouds
# Processing Record 40 of Set 1 | porto-vecchio
# clear sky
# Processing Record 41 of Set 1 | isangel
# clear sky
# Processing Record 42 of Set 1 | hobart
# overcast clouds
# Processing Record 43 of Set 1 | severo-kurilsk
# light rain
# Processing Record 44 of Set 1 | kapaa
# broken clouds
# Processing Record 45 of Set 1 | castro
# scattered clouds
# Processing Record 46 of Set 1 | saint-leu
# broken clouds
# Processing Record 47 of Set 1 | ippy
# broken clouds
# Processing Record 48 of Set 1 | chuy
# heavy intensity rain
# Processing Record 49 of Set 1 | avera
# broken clouds
# Processing Record 50 of Set 1 | aksarka
# overcast clouds
# Processing Record 1 of Set 2 | kazanka
# overcast clouds
# Processing Record 2 of Set 2 | padang
# light rain
# Processing Record 3 of Set 2 | aguimes
# few clouds
# Processing Record 4 of Set 2 | aykhal
# overcast clouds
# Processing Record 5 of Set 2 | barrow
# overcast clouds
# Processing Record 6 of Set 2 | mahebourg
# scattered clouds
# Processing Record 7 of Set 2 | carnarvon
# clear sky
# Processing Record 8 of Set 2 | kudahuvadhoo
# broken clouds
# Processing Record 9 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 2 | georgetown
# few clouds
# Processing Record 11 of Set 2 | kaitangata
# overcast clouds
# Processing Record 12 of Set 2 | port alfred
# clear sky
# Processing Record 13 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 2 | vaini
# few clouds
# Processing Record 15 of Set 2 | getulio vargas
# overcast clouds
# Processing Record 16 of Set 2 | kananga
# clear sky
# Processing Record 17 of Set 2 | cape town
# clear sky
# Processing Record 18 of Set 2 | punta arenas
# few clouds
# Processing Record 19 of Set 2 | matara
# scattered clouds
# Processing Record 20 of Set 2 | saskylakh
# overcast clouds
# Processing Record 21 of Set 2 | samarai
# overcast clouds
# Processing Record 22 of Set 2 | qaanaaq
# overcast clouds
# Processing Record 23 of Set 2 | tucuman
# light intensity drizzle
# Processing Record 24 of Set 2 | tete
# broken clouds
# Processing Record 25 of Set 2 | pithora
# overcast clouds
# Processing Record 26 of Set 2 | norfolk
# overcast clouds
# Processing Record 27 of Set 2 | east london
# clear sky
# Processing Record 28 of Set 2 | hambantota
# broken clouds
# Processing Record 29 of Set 2 | bluff
# few clouds
# Processing Record 30 of Set 2 | port elizabeth
# clear sky
# Processing Record 31 of Set 2 | ribeira grande
# broken clouds
# Processing Record 32 of Set 2 | ahipara
# light rain
# Processing Record 33 of Set 2 | alghero
# clear sky
# Processing Record 34 of Set 2 | duldurga
# scattered clouds
# Processing Record 35 of Set 2 | dingle
# moderate rain
# Processing Record 36 of Set 2 | evensk
# scattered clouds
# Processing Record 37 of Set 2 | naze
# broken clouds
# Processing Record 38 of Set 2 | verkhoyansk
# overcast clouds
# Processing Record 39 of Set 2 | sambava
# light rain
# Processing Record 40 of Set 2 | yumen
# few clouds
# Processing Record 41 of Set 2 | sibenik
# clear sky
# Processing Record 42 of Set 2 | egvekinot
# light rain
# Processing Record 43 of Set 2 | puerto ayora
# overcast clouds
# Processing Record 44 of Set 2 | atuona
# clear sky
# Processing Record 45 of Set 2 | dikson
# overcast clouds
# Processing Record 46 of Set 2 | ushuaia
# few clouds
# Processing Record 47 of Set 2 | hovd
# broken clouds
# Processing Record 48 of Set 2 | dillon
# overcast clouds
# Processing Record 49 of Set 2 | upernavik
# few clouds
# Processing Record 50 of Set 2 | lucapa
# clear sky
# Processing Record 1 of Set 3 | bengkulu
# overcast clouds
# Processing Record 2 of Set 3 | sao luiz gonzaga
# light rain
# Processing Record 3 of Set 3 | almaznyy
# overcast clouds
# Processing Record 4 of Set 3 | kavieng
# overcast clouds
# Processing Record 5 of Set 3 | san vicente
# overcast clouds
# Processing Record 6 of Set 3 | arraial do cabo
# scattered clouds
# Processing Record 7 of Set 3 | tirur
# overcast clouds
# Processing Record 8 of Set 3 | shouguang
# overcast clouds
# Processing Record 9 of Set 3 | russell
# clear sky
# Processing Record 10 of Set 3 | bosaso
# overcast clouds
# Processing Record 11 of Set 3 | iqaluit
# scattered clouds
# Processing Record 12 of Set 3 | bambous virieux
# light rain
# Processing Record 13 of Set 3 | mount gambier
# overcast clouds
# Processing Record 14 of Set 3 | shimoda
# broken clouds
# Processing Record 15 of Set 3 | hasaki
# scattered clouds
# Processing Record 16 of Set 3 | semirom
# clear sky
# Processing Record 17 of Set 3 | keene
# overcast clouds
# Processing Record 18 of Set 3 | arlit
# broken clouds
# Processing Record 19 of Set 3 | saint-philippe
# overcast clouds
# Processing Record 20 of Set 3 | margate
# scattered clouds
# Processing Record 21 of Set 3 | tautira
# light rain
# Processing Record 22 of Set 3 | sao jose da coroa grande
# scattered clouds
# Processing Record 23 of Set 3 | fomboni
# clear sky
# Processing Record 24 of Set 3 | roald
# broken clouds
# Processing Record 25 of Set 3 | salalah
# overcast clouds
# Processing Record 26 of Set 3 | santa quiteria do maranhao
# few clouds
# Processing Record 27 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 3 | cortez
# clear sky
# Processing Record 30 of Set 3 | kodiak
# clear sky
# Processing Record 31 of Set 3 | lata
# clear sky
# Processing Record 32 of Set 3 | arkhangelskaya
# light rain
# Processing Record 33 of Set 3 | antalaha
# light rain
# Processing Record 34 of Set 3 | luau
# clear sky
# Processing Record 35 of Set 3 | tasiilaq
# overcast clouds
# Processing Record 36 of Set 3 | avarua
# scattered clouds
# Processing Record 37 of Set 3 | barra do garcas
# clear sky
# Processing Record 38 of Set 3 | thompson
# overcast clouds
# Processing Record 39 of Set 3 | roebourne
# clear sky
# Processing Record 40 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 41 of Set 3 | xiaoshi
# overcast clouds
# Processing Record 42 of Set 3 | ponferrada
# few clouds
# Processing Record 43 of Set 3 | souillac
# light rain
# Processing Record 44 of Set 3 | chirongui
# scattered clouds
# Processing Record 45 of Set 3 | ponta do sol
# broken clouds
# Processing Record 46 of Set 3 | leningradskiy
# clear sky
# Processing Record 47 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 48 of Set 3 | oksfjord
# broken clouds
# Processing Record 49 of Set 3 | chengde
# overcast clouds
# Processing Record 50 of Set 3 | tual
# overcast clouds
# Processing Record 1 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 4 | khor
# overcast clouds
# Processing Record 3 of Set 4 | fort morgan
# clear sky
# Processing Record 4 of Set 4 | bethel
# moderate rain
# Processing Record 5 of Set 4 | ternate
# overcast clouds
# Processing Record 6 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 4 | westport
# overcast clouds
# Processing Record 8 of Set 4 | sorland
# scattered clouds
# Processing Record 9 of Set 4 | saint george
# clear sky
# Processing Record 10 of Set 4 | namibe
# clear sky
# Processing Record 11 of Set 4 | port shepstone
# clear sky
# Processing Record 12 of Set 4 | itambacuri
# overcast clouds
# Processing Record 13 of Set 4 | khudumelapye
# broken clouds
# Processing Record 14 of Set 4 | ancud
# light rain
# Processing Record 15 of Set 4 | fortuna
# broken clouds
# Processing Record 16 of Set 4 | zhuhai
# few clouds
# Processing Record 17 of Set 4 | manadhoo
# few clouds
# Processing Record 18 of Set 4 | necochea
# clear sky
# Processing Record 19 of Set 4 | porto velho
# few clouds
# Processing Record 20 of Set 4 | dryden
# clear sky
# Processing Record 21 of Set 4 | porto de moz
# scattered clouds
# Processing Record 22 of Set 4 | shieli
# clear sky
# Processing Record 23 of Set 4 | hailar
# few clouds
# Processing Record 24 of Set 4 | kharp
# light rain
# Processing Record 25 of Set 4 | orzu
# clear sky
# Processing Record 26 of Set 4 | hithadhoo
# broken clouds
# Processing Record 27 of Set 4 | cap-aux-meules
# few clouds
# Processing Record 28 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 4 | port hardy
# fog
# Processing Record 30 of Set 4 | coquimbo
# light rain
# Processing Record 31 of Set 4 | tiksi
# overcast clouds
# Processing Record 32 of Set 4 | cavalcante
# clear sky
# Processing Record 33 of Set 4 | lorengau
# overcast clouds
# Processing Record 34 of Set 4 | laguna
# clear sky
# Processing Record 35 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 36 of Set 4 | pangkalanbuun
# overcast clouds
# Processing Record 37 of Set 4 | kaeo
# overcast clouds
# Processing Record 38 of Set 4 | san patricio
# scattered clouds
# Processing Record 39 of Set 4 | negele
# City not found. Skipping...
# Processing Record 40 of Set 4 | clyde river
# light snow
# Processing Record 41 of Set 4 | vardo
# broken clouds
# Processing Record 42 of Set 4 | chimore
# few clouds
# Processing Record 43 of Set 4 | tromso
# clear sky
# Processing Record 44 of Set 4 | khatanga
# clear sky
# Processing Record 45 of Set 4 | broken hill
# clear sky
# Processing Record 46 of Set 4 | puerto narino
# scattered clouds
# Processing Record 47 of Set 4 | airai
# overcast clouds
# Processing Record 48 of Set 4 | cidreira
# overcast clouds
# Processing Record 49 of Set 4 | rundu
# clear sky
# Processing Record 50 of Set 4 | lompoc
# clear sky
# Processing Record 1 of Set 5 | sena madureira
# few clouds
# Processing Record 2 of Set 5 | diplo
# scattered clouds
# Processing Record 3 of Set 5 | bytow
# scattered clouds
# Processing Record 4 of Set 5 | maues
# scattered clouds
# Processing Record 5 of Set 5 | winnemucca
# clear sky
# Processing Record 6 of Set 5 | xining
# overcast clouds
# Processing Record 7 of Set 5 | muros
# broken clouds
# Processing Record 8 of Set 5 | mekhelta
# City not found. Skipping...
# Processing Record 9 of Set 5 | muhos
# scattered clouds
# Processing Record 10 of Set 5 | champerico
# few clouds
# Processing Record 11 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 5 | bredasdorp
# clear sky
# Processing Record 13 of Set 5 | tshikapa
# clear sky
# Processing Record 14 of Set 5 | chihuahua
# few clouds
# Processing Record 15 of Set 5 | pevek
# clear sky
# Processing Record 16 of Set 5 | hilo
# broken clouds
# Processing Record 17 of Set 5 | mendeleyevsk
# scattered clouds
# Processing Record 18 of Set 5 | utete
# overcast clouds
# Processing Record 19 of Set 5 | merauke
# overcast clouds
# Processing Record 20 of Set 5 | nemuro
# overcast clouds
# Processing Record 21 of Set 5 | chokurdakh
# overcast clouds
# Processing Record 22 of Set 5 | tambau
# few clouds
# Processing Record 23 of Set 5 | ilulissat
# scattered clouds
# Processing Record 24 of Set 5 | urucui
# clear sky
# Processing Record 25 of Set 5 | nuuk
# light rain
# Processing Record 26 of Set 5 | pisco
# smoke
# Processing Record 27 of Set 5 | saldanha
# clear sky
# Processing Record 28 of Set 5 | norman wells
# broken clouds
# Processing Record 29 of Set 5 | kirakira
# overcast clouds
# Processing Record 30 of Set 5 | boueni
# scattered clouds
# Processing Record 31 of Set 5 | ambilobe
# few clouds
# Processing Record 32 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 5 | basco
# broken clouds
# Processing Record 34 of Set 5 | provideniya
# overcast clouds
# Processing Record 35 of Set 5 | kavaratti
# overcast clouds
# Processing Record 36 of Set 5 | bogatyr
# moderate rain
# Processing Record 37 of Set 5 | vieste
# clear sky
# Processing Record 38 of Set 5 | donetsk
# overcast clouds
# Processing Record 39 of Set 5 | galeana
# scattered clouds
# Processing Record 40 of Set 5 | bedesa
# light rain
# Processing Record 41 of Set 5 | emerald
# broken clouds
# Processing Record 42 of Set 5 | mollendo
# broken clouds
# Processing Record 43 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 5 | biltine
# scattered clouds
# Processing Record 45 of Set 5 | rio grande
# moderate rain
# Processing Record 46 of Set 5 | srandakan
# broken clouds
# Processing Record 47 of Set 5 | deep river
# broken clouds
# Processing Record 48 of Set 5 | talnakh
# scattered clouds
# Processing Record 49 of Set 5 | cody
# clear sky
# Processing Record 50 of Set 5 | atambua
# overcast clouds
# Processing Record 1 of Set 6 | fonte boa
# few clouds
# Processing Record 2 of Set 6 | sterling
# broken clouds
# Processing Record 3 of Set 6 | bowen
# scattered clouds
# Processing Record 4 of Set 6 | birin
# overcast clouds
# Processing Record 5 of Set 6 | chatra
# overcast clouds
# Processing Record 6 of Set 6 | tabou
# broken clouds
# Processing Record 7 of Set 6 | gyongyossolymos
# few clouds
# Processing Record 8 of Set 6 | dondo
# scattered clouds
# Processing Record 9 of Set 6 | cajamarca
# clear sky
# Processing Record 10 of Set 6 | toumodi
# moderate rain
# Processing Record 11 of Set 6 | zhangye
# scattered clouds
# Processing Record 12 of Set 6 | embonas
# clear sky
# Processing Record 13 of Set 6 | sfantu gheorghe
# overcast clouds
# Processing Record 14 of Set 6 | iskateley
# overcast clouds
# Processing Record 15 of Set 6 | yatou
# light rain
# Processing Record 16 of Set 6 | big spring
# clear sky
# Processing Record 17 of Set 6 | cabo san lucas
# clear sky
# Processing Record 18 of Set 6 | upington
# clear sky
# Processing Record 19 of Set 6 | inhambane
# scattered clouds
# Processing Record 20 of Set 6 | kieta
# overcast clouds
# Processing Record 21 of Set 6 | caravelas
# broken clouds
# Processing Record 22 of Set 6 | malangwa
# overcast clouds
# Processing Record 23 of Set 6 | alofi
# overcast clouds
# Processing Record 24 of Set 6 | sept-iles
# heavy intensity rain
# Processing Record 25 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 26 of Set 6 | palu
# broken clouds
# Processing Record 27 of Set 6 | teknaf
# overcast clouds
# Processing Record 28 of Set 6 | durban
# clear sky
# Processing Record 29 of Set 6 | edgewater
# overcast clouds
# Processing Record 30 of Set 6 | katsuura
# broken clouds
# Processing Record 31 of Set 6 | bairiki
# scattered clouds
# Processing Record 32 of Set 6 | longyearbyen
# scattered clouds
# Processing Record 33 of Set 6 | luderitz
# clear sky
# Processing Record 34 of Set 6 | mayumba
# broken clouds
# Processing Record 35 of Set 6 | porto novo
# overcast clouds
# Processing Record 36 of Set 6 | bandarban
# overcast clouds
# Processing Record 37 of Set 6 | perevolotskiy
# clear sky
# Processing Record 38 of Set 6 | fairlie
# overcast clouds
# Processing Record 39 of Set 6 | nome
# overcast clouds
# Processing Record 40 of Set 6 | touros
# scattered clouds
# Processing Record 41 of Set 6 | katobu
# overcast clouds
# Processing Record 42 of Set 6 | palmer
# broken clouds
# Processing Record 43 of Set 6 | saint-pierre
# overcast clouds
# Processing Record 44 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 6 | guerrero negro
# few clouds
# Processing Record 47 of Set 6 | gatesville
# clear sky
# Processing Record 48 of Set 6 | osa
# broken clouds
# Processing Record 49 of Set 6 | lake havasu city
# clear sky
# Processing Record 50 of Set 6 | lavrentiya
# overcast clouds
# Processing Record 1 of Set 7 | wukari
# overcast clouds
# Processing Record 2 of Set 7 | santos dumont
# broken clouds
# Processing Record 3 of Set 7 | perelyub
# clear sky
# Processing Record 4 of Set 7 | bambanglipuro
# broken clouds
# Processing Record 5 of Set 7 | bonavista
# overcast clouds
# Processing Record 6 of Set 7 | cairns
# overcast clouds
# Processing Record 7 of Set 7 | cumra
# broken clouds
# Processing Record 8 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 7 | nagornyy
# overcast clouds
# Processing Record 10 of Set 7 | el alto
# few clouds
# Processing Record 11 of Set 7 | hurghada
# clear sky
# Processing Record 12 of Set 7 | okhotsk
# overcast clouds
# Processing Record 13 of Set 7 | marv dasht
# City not found. Skipping...
# Processing Record 14 of Set 7 | kruisfontein
# clear sky
# Processing Record 15 of Set 7 | chumphon
# broken clouds
# Processing Record 16 of Set 7 | mackay
# broken clouds
# Processing Record 17 of Set 7 | peniche
# clear sky
# Processing Record 18 of Set 7 | axim
# broken clouds
# Processing Record 19 of Set 7 | guarapari
# scattered clouds
# Processing Record 20 of Set 7 | spirit river
# overcast clouds
# Processing Record 21 of Set 7 | elko
# clear sky
# Processing Record 22 of Set 7 | puerto del rosario
# broken clouds
# Processing Record 23 of Set 7 | trinidad
# few clouds
# Processing Record 24 of Set 7 | tongren
# overcast clouds
# Processing Record 25 of Set 7 | anloga
# overcast clouds
# Processing Record 26 of Set 7 | bathsheba
# scattered clouds
# Processing Record 27 of Set 7 | la ronge
# broken clouds
# Processing Record 28 of Set 7 | zhigansk
# overcast clouds
# Processing Record 29 of Set 7 | zaozerne
# overcast clouds
# Processing Record 30 of Set 7 | turukhansk
# overcast clouds
# Processing Record 31 of Set 7 | kumo
# overcast clouds
# Processing Record 32 of Set 7 | rio gallegos
# clear sky
# Processing Record 33 of Set 7 | torbay
# broken clouds
# Processing Record 34 of Set 7 | buren
# broken clouds
# Processing Record 35 of Set 7 | talavera de la reina
# clear sky
# Processing Record 36 of Set 7 | jablah
# few clouds
# Processing Record 37 of Set 7 | salinopolis
# clear sky
# Processing Record 38 of Set 7 | nelson bay
# light rain
# Processing Record 39 of Set 7 | camacha
# few clouds
# Processing Record 40 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 7 | sao filipe
# few clouds
# Processing Record 42 of Set 7 | marsaxlokk
# clear sky
# Processing Record 43 of Set 7 | rawson
# broken clouds
# Processing Record 44 of Set 7 | comodoro rivadavia
# clear sky
# Processing Record 45 of Set 7 | novosil
# scattered clouds
# Processing Record 46 of Set 7 | san isidro
# scattered clouds
# Processing Record 47 of Set 7 | vostok
# overcast clouds
# Processing Record 48 of Set 7 | poum
# overcast clouds
# Processing Record 49 of Set 7 | burgeo
# overcast clouds
# Processing Record 50 of Set 7 | along
# moderate rain
# Processing Record 1 of Set 8 | cherskiy
# overcast clouds
# Processing Record 2 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 3 of Set 8 | lingao
# broken clouds
# Processing Record 4 of Set 8 | segovia
# scattered clouds
# Processing Record 5 of Set 8 | thanh hoa
# broken clouds
# Processing Record 6 of Set 8 | raudeberg
# overcast clouds
# Processing Record 7 of Set 8 | naliya
# few clouds
# Processing Record 8 of Set 8 | zyryanka
# broken clouds
# Processing Record 9 of Set 8 | high level
# scattered clouds
# Processing Record 10 of Set 8 | tongzi
# broken clouds
# Processing Record 11 of Set 8 | adet
# overcast clouds
# Processing Record 12 of Set 8 | san juan del sur
# overcast clouds
# Processing Record 13 of Set 8 | pando
# moderate rain
# Processing Record 14 of Set 8 | qaqortoq
# few clouds
# Processing Record 15 of Set 8 | itaituba
# few clouds
# Processing Record 16 of Set 8 | trujillo
# fog
# Processing Record 17 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 8 | pontes e lacerda
# clear sky
# Processing Record 19 of Set 8 | herrin
# few clouds
# Processing Record 20 of Set 8 | faanui
# few clouds
# Processing Record 21 of Set 8 | sakakah
# clear sky
# Processing Record 22 of Set 8 | jaque
# moderate rain
# Processing Record 23 of Set 8 | hamilton
# clear sky
# Processing Record 24 of Set 8 | sur
# overcast clouds
# Processing Record 25 of Set 8 | serta
# clear sky
# Processing Record 26 of Set 8 | chikola
# overcast clouds
# Processing Record 27 of Set 8 | meulaboh
# overcast clouds
# Processing Record 28 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 8 | celestun
# scattered clouds
# Processing Record 30 of Set 8 | sayan
# broken clouds
# Processing Record 31 of Set 8 | bulungu
# few clouds
# Processing Record 32 of Set 8 | tuatapere
# broken clouds
# Processing Record 33 of Set 8 | pangai
# scattered clouds
# Processing Record 34 of Set 8 | vao
# broken clouds
# Processing Record 35 of Set 8 | amapa
# few clouds
# Processing Record 36 of Set 8 | alice springs
# overcast clouds
# Processing Record 37 of Set 8 | piracanjuba
# scattered clouds
# Processing Record 38 of Set 8 | klaksvik
# broken clouds
# Processing Record 39 of Set 8 | hagere selam
# overcast clouds
# Processing Record 40 of Set 8 | faya
# broken clouds
# Processing Record 41 of Set 8 | hervey bay
# few clouds
# Processing Record 42 of Set 8 | chikwawa
# overcast clouds
# Processing Record 43 of Set 8 | esperance
# broken clouds
# Processing Record 44 of Set 8 | venado tuerto
# overcast clouds
# Processing Record 45 of Set 8 | christchurch
# light rain
# Processing Record 46 of Set 8 | san policarpo
# overcast clouds
# Processing Record 47 of Set 8 | barra do corda
# clear sky
# Processing Record 48 of Set 8 | ayorou
# scattered clouds
# Processing Record 49 of Set 8 | mehamn
# clear sky
# Processing Record 50 of Set 8 | san cristobal
# clear sky
# Processing Record 1 of Set 9 | sinnamary
# overcast clouds
# Processing Record 2 of Set 9 | cardoso
# clear sky
# Processing Record 3 of Set 9 | maragogi
# scattered clouds
# Processing Record 4 of Set 9 | rangapara
# light rain
# Processing Record 5 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 9 | tilichiki
# scattered clouds
# Processing Record 7 of Set 9 | aklavik
# broken clouds
# Processing Record 8 of Set 9 | utuado
# overcast clouds
# Processing Record 9 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 9 | san quintin
# clear sky
# Processing Record 11 of Set 9 | mindelo
# few clouds
# Processing Record 12 of Set 9 | karpuninskiy
# City not found. Skipping...
# Processing Record 13 of Set 9 | namatanai
# overcast clouds
# Processing Record 14 of Set 9 | zuwarah
# scattered clouds
# Processing Record 15 of Set 9 | golspie
# overcast clouds
# Processing Record 16 of Set 9 | scunthorpe
# broken clouds
# Processing Record 17 of Set 9 | tura
# overcast clouds
# Processing Record 18 of Set 9 | sangar
# light rain
# Processing Record 19 of Set 9 | antsohihy
# clear sky
# Processing Record 20 of Set 9 | whitehorse
# broken clouds
# Processing Record 21 of Set 9 | beringovskiy
# overcast clouds
# Processing Record 22 of Set 9 | lubango
# clear sky
# Processing Record 23 of Set 9 | yoichi
# broken clouds
# Processing Record 24 of Set 9 | peremyshl
# few clouds
# Processing Record 25 of Set 9 | west point
# broken clouds
# Processing Record 26 of Set 9 | la cruz
# broken clouds
# Processing Record 27 of Set 9 | jaisalmer
# clear sky
# Processing Record 28 of Set 9 | sulphur
# scattered clouds
# Processing Record 29 of Set 9 | walvis bay
# clear sky
# Processing Record 30 of Set 9 | portland
# few clouds
# Processing Record 31 of Set 9 | batagay-alyta
# overcast clouds
# Processing Record 32 of Set 9 | zelenogradsk
# clear sky
# Processing Record 33 of Set 9 | benjamin constant
# scattered clouds
# Processing Record 34 of Set 9 | punta alta
# clear sky
# Processing Record 35 of Set 9 | havoysund
# few clouds
# Processing Record 36 of Set 9 | naryan-mar
# overcast clouds
# Processing Record 37 of Set 9 | jishou
# overcast clouds
# Processing Record 38 of Set 9 | cabedelo
# scattered clouds
# Processing Record 39 of Set 9 | athabasca
# overcast clouds
# Processing Record 40 of Set 9 | zhadovka
# moderate rain
# Processing Record 41 of Set 9 | kununurra
# scattered clouds
# Processing Record 42 of Set 9 | olavarria
# overcast clouds
# Processing Record 43 of Set 9 | santa marta
# broken clouds
# Processing Record 44 of Set 9 | sioux lookout
# scattered clouds
# Processing Record 45 of Set 9 | camaguey
# overcast clouds
# Processing Record 46 of Set 9 | mount isa
# overcast clouds
# Processing Record 47 of Set 9 | lusambo
# scattered clouds
# Processing Record 48 of Set 9 | olafsvik
# overcast clouds
# Processing Record 49 of Set 9 | buraydah
# clear sky
# Processing Record 50 of Set 9 | hofn
# light rain
# Processing Record 1 of Set 10 | kimbe
# overcast clouds
# Processing Record 2 of Set 10 | ivanivka
# overcast clouds
# Processing Record 3 of Set 10 | honningsvag
# clear sky
# Processing Record 4 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 5 of Set 10 | luena
# clear sky
# Processing Record 6 of Set 10 | kandrian
# overcast clouds
# Processing Record 7 of Set 10 | mizan teferi
# overcast clouds
# Processing Record 8 of Set 10 | sitka
# few clouds
# Processing Record 9 of Set 10 | krasnyy yar
# scattered clouds
# Processing Record 10 of Set 10 | japura
# overcast clouds
# Processing Record 11 of Set 10 | diamantino
# clear sky
# Processing Record 12 of Set 10 | rajampet
# overcast clouds
# Processing Record 13 of Set 10 | coihaique
# overcast clouds
# Processing Record 14 of Set 10 | liku
# broken clouds
# Processing Record 15 of Set 10 | ishigaki
# few clouds
# Processing Record 16 of Set 10 | aswan
# clear sky
# Processing Record 17 of Set 10 | pinerovka
# clear sky
# Processing Record 18 of Set 10 | kitob
# clear sky
# Processing Record 19 of Set 10 | ojinaga
# clear sky
# Processing Record 20 of Set 10 | pouembout
# overcast clouds
# Processing Record 21 of Set 10 | almaty
# broken clouds
# Processing Record 22 of Set 10 | tateyama
# broken clouds
# Processing Record 23 of Set 10 | tres arroyos
# clear sky
# Processing Record 24 of Set 10 | denton
# clear sky
# Processing Record 25 of Set 10 | srednekolymsk
# overcast clouds
# Processing Record 26 of Set 10 | broome
# broken clouds
# Processing Record 27 of Set 10 | osakarovka
# clear sky
# Processing Record 28 of Set 10 | butembo
# broken clouds
# Processing Record 29 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 10 | mareeba
# overcast clouds
# Processing Record 31 of Set 10 | aasiaat
# broken clouds
# Processing Record 32 of Set 10 | oranjemund
# clear sky
# Processing Record 33 of Set 10 | oranjestad
# scattered clouds
# Processing Record 34 of Set 10 | korocha
# clear sky
# Processing Record 35 of Set 10 | buseresere
# overcast clouds
# Processing Record 36 of Set 10 | carballo
# broken clouds
# Processing Record 37 of Set 10 | teya
# scattered clouds
# Processing Record 38 of Set 10 | gazli
# clear sky
# Processing Record 39 of Set 10 | zaysan
# broken clouds
# Processing Record 40 of Set 10 | aripuana
# clear sky
# Processing Record 41 of Set 10 | yenagoa
# overcast clouds
# Processing Record 42 of Set 10 | kibaya
# scattered clouds
# Processing Record 43 of Set 10 | karoi
# broken clouds
# Processing Record 44 of Set 10 | badaojiang
# City not found. Skipping...
# Processing Record 45 of Set 10 | tuntum
# clear sky
# Processing Record 46 of Set 10 | male
# broken clouds
# Processing Record 47 of Set 10 | borovskoy
# few clouds
# Processing Record 48 of Set 10 | madinat sittah uktubar
# clear sky
# Processing Record 49 of Set 10 | kloulklubed
# moderate rain
# Processing Record 50 of Set 10 | hammerfest
# clear sky
# Processing Record 1 of Set 11 | hobyo
# broken clouds
# Processing Record 2 of Set 11 | pochutla
# scattered clouds
# Processing Record 3 of Set 11 | erenhot
# overcast clouds
# Processing Record 4 of Set 11 | olden
# light rain
# Processing Record 5 of Set 11 | husavik
# overcast clouds
# Processing Record 6 of Set 11 | los llanos de aridane
# few clouds
# Processing Record 7 of Set 11 | dunedin
# overcast clouds
# Processing Record 8 of Set 11 | jalu
# clear sky
# Processing Record 9 of Set 11 | nioro
# scattered clouds
# Processing Record 10 of Set 11 | makakilo city
# clear sky
# Processing Record 11 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 11 | spokane
# clear sky
# Processing Record 13 of Set 11 | geraldton
# few clouds
# Processing Record 14 of Set 11 | belorechensk
# moderate rain
# Processing Record 15 of Set 11 | pemberton
# broken clouds
# Processing Record 16 of Set 11 | fairbanks
# smoke
# Processing Record 17 of Set 11 | flin flon
# broken clouds
# Processing Record 18 of Set 11 | nicoya
# overcast clouds
# Processing Record 19 of Set 11 | aljezur
# clear sky
# Processing Record 20 of Set 11 | manokwari
# overcast clouds
# Processing Record 21 of Set 11 | mulege
# clear sky
# Processing Record 22 of Set 11 | san luis
# overcast clouds
# Processing Record 23 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 11 | brahmapuri
# City not found. Skipping...
# Processing Record 25 of Set 11 | la rioja
# overcast clouds
# Processing Record 26 of Set 11 | wenling
# overcast clouds
# Processing Record 27 of Set 11 | sao gabriel da cachoeira
# broken clouds
# Processing Record 28 of Set 11 | grindavik
# overcast clouds
# Processing Record 29 of Set 11 | matamoros
# broken clouds
# Processing Record 30 of Set 11 | esil
# broken clouds
# Processing Record 31 of Set 11 | alyangula
# overcast clouds
# Processing Record 32 of Set 11 | nizwa
# overcast clouds
# Processing Record 33 of Set 11 | constitucion
# clear sky
# Processing Record 34 of Set 11 | jiazi
# overcast clouds
# Processing Record 35 of Set 11 | mnogovershinnyy
# clear sky
# Processing Record 36 of Set 11 | cascais
# few clouds
# Processing Record 37 of Set 11 | hvolsvollur
# overcast clouds
# Processing Record 38 of Set 11 | uwajima
# overcast clouds
# Processing Record 39 of Set 11 | udachnyy
# overcast clouds
# Processing Record 40 of Set 11 | haines junction
# broken clouds
# Processing Record 41 of Set 11 | goderich
# broken clouds
# Processing Record 42 of Set 11 | nisia floresta
# broken clouds
# Processing Record 43 of Set 11 | road town
# few clouds
# Processing Record 44 of Set 11 | albury
# scattered clouds
# Processing Record 45 of Set 11 | asau
# overcast clouds
# Processing Record 46 of Set 11 | gazojak
# clear sky
# Processing Record 47 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 11 | cuiluan
# overcast clouds
# Processing Record 49 of Set 11 | padre bernardo
# scattered clouds
# Processing Record 50 of Set 11 | havre-saint-pierre
# broken clouds
# Processing Record 1 of Set 12 | khajuraho
# overcast clouds
# Processing Record 2 of Set 12 | pingliang
# broken clouds
# Processing Record 3 of Set 12 | yar-sale
# overcast clouds
# Processing Record 4 of Set 12 | sayyan
# overcast clouds
# Processing Record 5 of Set 12 | kawasaki
# few clouds
# Processing Record 6 of Set 12 | taylor
# scattered clouds
# Processing Record 7 of Set 12 | sabha
# clear sky
# Processing Record 8 of Set 12 | sobolevo
# clear sky
# Processing Record 9 of Set 12 | verdun
# overcast clouds
# Processing Record 10 of Set 12 | matagami
# broken clouds
# Processing Record 11 of Set 12 | palaikastron
# clear sky
# Processing Record 12 of Set 12 | wad rawah
# broken clouds
# Processing Record 13 of Set 12 | te anau
# broken clouds
# Processing Record 14 of Set 12 | cayenne
# overcast clouds
# Processing Record 15 of Set 12 | atasu
# clear sky
# Processing Record 16 of Set 12 | southbridge
# overcast clouds
# Processing Record 17 of Set 12 | samfya
# few clouds
# Processing Record 18 of Set 12 | north bend
# overcast clouds
# Processing Record 19 of Set 12 | levice
# broken clouds
# Processing Record 20 of Set 12 | luwuk
# broken clouds
# Processing Record 21 of Set 12 | pechenga
# clear sky
# Processing Record 22 of Set 12 | uzhhorod
# clear sky
# Processing Record 23 of Set 12 | san onofre
# broken clouds
# Processing Record 24 of Set 12 | zharkovskiy
# broken clouds
# Processing Record 25 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 12 | newark
# mist
# Processing Record 27 of Set 12 | camabatela
# clear sky
# Processing Record 28 of Set 12 | kiama
# light rain
# Processing Record 29 of Set 12 | santa fe
# light rain
# Processing Record 30 of Set 12 | adrar
# clear sky
# Processing Record 31 of Set 12 | terrace
# broken clouds
# Processing Record 32 of Set 12 | saint-augustin
# overcast clouds
# Processing Record 33 of Set 12 | ridgecrest
# clear sky
# Processing Record 34 of Set 12 | tecoanapa
# broken clouds
# Processing Record 35 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 12 | opuwo
# clear sky
# Processing Record 37 of Set 12 | punta gorda
# clear sky
# Processing Record 38 of Set 12 | oktyabrskiy
# light rain
# Processing Record 39 of Set 12 | yulara
# overcast clouds
# Processing Record 40 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 12 | ixtapa
# broken clouds
# Processing Record 42 of Set 12 | laje
# scattered clouds
# Processing Record 43 of Set 12 | verkhnevilyuysk
# overcast clouds
# Processing Record 44 of Set 12 | homer
# overcast clouds
# Processing Record 45 of Set 12 | ostersund
# broken clouds
# Processing Record 46 of Set 12 | beloha
# few clouds
# Processing Record 47 of Set 12 | marsh harbour
# clear sky
# Processing Record 48 of Set 12 | sibolga
# overcast clouds
# Processing Record 49 of Set 12 | hami
# broken clouds
# Processing Record 50 of Set 12 | colares
# few clouds
# Processing Record 1 of Set 13 | ghanzi
# light rain
# Processing Record 2 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 3 of Set 13 | grand gaube
# few clouds
# Processing Record 4 of Set 13 | labuan
# few clouds
# Processing Record 5 of Set 13 | bulawayo
# few clouds
# Processing Record 6 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 7 of Set 13 | kant
# overcast clouds
# Processing Record 8 of Set 13 | kanigoro
# broken clouds
# Processing Record 9 of Set 13 | gilbues
# clear sky
# Processing Record 10 of Set 13 | nangomba
# overcast clouds
# Processing Record 11 of Set 13 | berlevag
# clear sky
# Processing Record 12 of Set 13 | ostrovnoy
# overcast clouds
# Processing Record 13 of Set 13 | princeton
# few clouds
# Processing Record 14 of Set 13 | sant feliu de guixols
# scattered clouds
# Processing Record 15 of Set 13 | zdvinsk
# broken clouds
# Processing Record 16 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 13 | nuevo progreso
# clear sky
# Processing Record 18 of Set 13 | pacific grove
# haze
# Processing Record 19 of Set 13 | acapulco
# broken clouds
# Processing Record 20 of Set 13 | pangnirtung
# fog
# Processing Record 21 of Set 13 | pangoa
# broken clouds
# Processing Record 22 of Set 13 | sape
# broken clouds
# Processing Record 23 of Set 13 | kula
# scattered clouds
# Processing Record 24 of Set 13 | green river
# clear sky
# Processing Record 25 of Set 13 | kampot
# clear sky
# Processing Record 26 of Set 13 | kinna
# overcast clouds
# Processing Record 27 of Set 13 | cauquenes
# clear sky
# Processing Record 28 of Set 13 | bantou
# overcast clouds
# Processing Record 29 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 13 | cordele
# scattered clouds
# Processing Record 31 of Set 13 | juneau
# clear sky
# Processing Record 32 of Set 13 | kem
# broken clouds
# Processing Record 33 of Set 13 | ilhabela
# broken clouds
# Processing Record 34 of Set 13 | santa cruz
# few clouds
# Processing Record 35 of Set 13 | kuytun
# broken clouds
# Processing Record 36 of Set 13 | suda
# scattered clouds
# Processing Record 37 of Set 13 | sicuani
# clear sky
# Processing Record 38 of Set 13 | raga
# overcast clouds
# Processing Record 39 of Set 13 | nishihara
# scattered clouds
# Processing Record 40 of Set 13 | ilo
# clear sky
# Processing Record 41 of Set 13 | belaya gora
# light rain
# Processing Record 42 of Set 13 | talaya
# broken clouds
# Processing Record 43 of Set 13 | safaga
# clear sky
# Processing Record 44 of Set 13 | vestmanna
# overcast clouds
# Processing Record 45 of Set 13 | dharchula
# overcast clouds
# Processing Record 46 of Set 13 | fort smith
# clear sky
# Processing Record 47 of Set 13 | soritor
# broken clouds
# Processing Record 48 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 13 | presidencia roque saenz pena
# overcast clouds
# Processing Record 50 of Set 13 | amahai
# overcast clouds
# Processing Record 1 of Set 14 | eureka
# clear sky
# Processing Record 2 of Set 14 | belyy yar
# clear sky
# Processing Record 3 of Set 14 | nador
# clear sky
# Processing Record 4 of Set 14 | manono
# clear sky
# Processing Record 5 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 14 | samaipata
# scattered clouds
# Processing Record 7 of Set 14 | andenes
# scattered clouds
# Processing Record 8 of Set 14 | nouadhibou
# sand
# Processing Record 9 of Set 14 | springfield
# clear sky
# Processing Record 10 of Set 14 | topliceni
# overcast clouds
# Processing Record 11 of Set 14 | hornepayne
# scattered clouds
# Processing Record 12 of Set 14 | saint-louis
# clear sky
# Processing Record 13 of Set 14 | sabzevar
# few clouds
# Processing Record 14 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 14 | laem sing
# scattered clouds
# Processing Record 16 of Set 14 | ledyard
# heavy intensity rain
# Processing Record 17 of Set 14 | veraval
# overcast clouds
# Processing Record 18 of Set 14 | muncar
# overcast clouds
# Processing Record 19 of Set 14 | kamina
# clear sky
# Processing Record 20 of Set 14 | college
# smoke
# Processing Record 21 of Set 14 | shymkent
# clear sky
# Processing Record 22 of Set 14 | kouqian
# overcast clouds
# Processing Record 23 of Set 14 | banda aceh
# light rain
# Processing Record 24 of Set 14 | rocha
# overcast clouds
# Processing Record 25 of Set 14 | miranda de ebro
# overcast clouds
# Processing Record 26 of Set 14 | byron bay
# broken clouds
# Processing Record 27 of Set 14 | itarema
# few clouds
# Processing Record 28 of Set 14 | maruim
# clear sky
# Processing Record 29 of Set 14 | ampanihy
# clear sky
# Processing Record 30 of Set 14 | ostroleka
# overcast clouds
# Processing Record 31 of Set 14 | lerida
# heavy intensity rain
# Processing Record 32 of Set 14 | waw
# overcast clouds
# Processing Record 33 of Set 14 | ranong
# overcast clouds
# Processing Record 34 of Set 14 | gizo
# light rain
# Processing Record 35 of Set 14 | nizhniy tagil-39
# City not found. Skipping...
# Processing Record 36 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 14 | najran
# overcast clouds
# Processing Record 38 of Set 14 | bida
# broken clouds
# Processing Record 39 of Set 14 | puerto leguizamo
# scattered clouds
# Processing Record 40 of Set 14 | baytown
# broken clouds
# Processing Record 41 of Set 14 | scarborough
# broken clouds
# Processing Record 42 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 14 | dong hoi
# scattered clouds
# Processing Record 44 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 45 of Set 14 | riyadh
# few clouds
# Processing Record 46 of Set 14 | locri
# clear sky
# Processing Record 47 of Set 14 | santa isabel do rio negro
# broken clouds
# Processing Record 48 of Set 14 | tigil
# few clouds
# Processing Record 49 of Set 14 | miramar
# clear sky
# Processing Record 50 of Set 14 | praya
# few clouds
# Processing Record 1 of Set 15 | ilinskoye-khovanskoye
# few clouds
# Processing Record 2 of Set 15 | mgandu
# broken clouds
# Processing Record 3 of Set 15 | kolobrzeg
# scattered clouds
# Processing Record 4 of Set 15 | sri aman
# broken clouds
# Processing Record 5 of Set 15 | ilovita
# scattered clouds
# Processing Record 6 of Set 15 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 7 of Set 15 | lugo
# scattered clouds
# Processing Record 8 of Set 15 | khanpur
# clear sky
# Processing Record 9 of Set 15 | sungaipenuh
# overcast clouds
# Processing Record 10 of Set 15 | ostrovskoye
# scattered clouds
# Processing Record 11 of Set 15 | erzin
# clear sky
# Processing Record 12 of Set 15 | datong
# scattered clouds
# Processing Record 13 of Set 15 | belawan
# overcast clouds
# Processing Record 14 of Set 15 | dalbandin
# scattered clouds
# Processing Record 15 of Set 15 | paita
# few clouds
# Processing Record 16 of Set 15 | beliator
# overcast clouds
# Processing Record 17 of Set 15 | bavly
# broken clouds
# Processing Record 18 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 15 | vieques
# haze
# Processing Record 20 of Set 15 | sao felix do xingu
# clear sky
# Processing Record 21 of Set 15 | rovaniemi
# clear sky
# Processing Record 22 of Set 15 | severo-yeniseyskiy
# scattered clouds
# Processing Record 23 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 15 | gaziantep
# clear sky
# Processing Record 25 of Set 15 | shu
# broken clouds
# Processing Record 26 of Set 15 | havelock
# scattered clouds
# Processing Record 27 of Set 15 | vitim
# broken clouds
# Processing Record 28 of Set 15 | goias
# clear sky
# Processing Record 29 of Set 15 | kupino
# broken clouds
# Processing Record 30 of Set 15 | mihijam
# overcast clouds
# Processing Record 31 of Set 15 | olinda
# broken clouds
# Processing Record 32 of Set 15 | yellamanchili
# City not found. Skipping...
# Processing Record 33 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 15 | korla
# clear sky
# Processing Record 35 of Set 15 | hualmay
# broken clouds
# Processing Record 36 of Set 15 | beboto
# scattered clouds
# Processing Record 37 of Set 15 | palma del rio
# clear sky
# Processing Record 38 of Set 15 | safaqis
# City not found. Skipping...
# Processing Record 39 of Set 15 | yamoussoukro
# light rain
# Processing Record 40 of Set 15 | concarneau
# overcast clouds
# Processing Record 41 of Set 15 | puerto penasco
# clear sky
# Processing Record 42 of Set 15 | milkovo
# clear sky
# Processing Record 43 of Set 15 | denpasar
# scattered clouds
# Processing Record 44 of Set 15 | batagay
# overcast clouds
# Processing Record 45 of Set 15 | klyuchi
# few clouds
# Processing Record 46 of Set 15 | wanxian
# scattered clouds
# Processing Record 47 of Set 15 | batavia
# clear sky
# Processing Record 48 of Set 15 | beeville
# clear sky
# Processing Record 49 of Set 15 | deputatskiy
# snow
# Processing Record 50 of Set 15 | dzerzhinskoye
# overcast clouds
# Processing Record 1 of Set 16 | tabarqah
# City not found. Skipping...
# Processing Record 2 of Set 16 | imperia
# clear sky
# Processing Record 3 of Set 16 | carahue
# overcast clouds
# Processing Record 4 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 16 | orasac
# clear sky
# Processing Record 6 of Set 16 | malakal
# broken clouds
# Processing Record 7 of Set 16 | la huacana
# broken clouds
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Nikolskoye      RU  59.7035   30.7861     80.49        61          11
# 1     Kahului      US  20.8947 -156.4700     80.62        72          40
# 2  Vila Velha      BR -20.3297  -40.2925     75.15        55          20
# 3      Bayeux      BR  -7.1250  -34.9322     77.63        83          75
# 4      Narsaq      GL  60.9167  -46.0500     55.62        66          19
#
#    Wind Speed Current Description
# 0        3.24          few clouds
# 1       12.66    scattered clouds
# 2       13.80          few clouds
# 3       16.11       broken clouds
# 4        4.07          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
